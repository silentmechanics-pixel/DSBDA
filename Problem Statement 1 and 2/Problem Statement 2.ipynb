# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Titanic.csv')
df.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
df.isnull().sum()
# Out:
# Name          0
# PClass        1
# Age         557
# Sex           0
# Survived      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name          0
# PClass        1
# Age         557
# Sex           0
# Survived      0
# dtype: int64

# %%
df['PClass'] = df['PClass'].fillna(df['PClass'].mode()[0])
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# Name        0
# PClass      0
# Age         0
# Sex         0
# Survived    0
# dtype: int64

# %%
df.describe()
# Out:
#                Age     Survived
# count  1313.000000  1313.000000
# mean     30.397989     0.342727
# std      10.816758     0.474802
# min       0.170000     0.000000
# 25%      26.000000     0.000000
# 50%      30.397989     0.000000
# 75%      30.397989     1.000000
# max      71.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1313 non-null   object
#  2   Age       1313 non-null   float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 51.4+ KB

# %%
df.shape
# Out:
# (1313, 5)

# %%
df.size
# Out:
# 6565

# %%
df.dtypes
# Out:
# Name         object
# PClass       object
# Age         float64
# Sex          object
# Survived      int64
# dtype: object

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.dtypes
# Out:
# Name        object
# PClass      object
# Age          int64
# Sex         object
# Survived     int64
# dtype: object

# %%
df.head()
# Out:
#                                             Name PClass  Age     Sex  Survived
# 0                   Allen, Miss Elisabeth Walton    1st   29  female         1
# 1                    Allison, Miss Helen Loraine    1st    2  female         0
# 2            Allison, Mr Hudson Joshua Creighton    1st   30    male         0
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st   25  female         0
# 4                  Allison, Master Hudson Trevor    1st    0    male         1

# %%
df = pd.get_dummies(df, columns = ['Sex'], dtype = int)

# %%
df.head()
# Out:
#                                             Name PClass  Age  Survived  \
# 0                   Allen, Miss Elisabeth Walton    1st   29         1
# 1                    Allison, Miss Helen Loraine    1st    2         0
# 2            Allison, Mr Hudson Joshua Creighton    1st   30         0
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st   25         0
# 4                  Allison, Master Hudson Trevor    1st    0         1
#
#    Sex_female  Sex_male
# 0           1         0
# 1           1         0
# 2           0         1
# 3           1         0
# 4           0         1
